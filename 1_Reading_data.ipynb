# %%
import pandas as pd
from pandas import DataFrame  #ezeket nem szoktak igy kiirni, ez helyett viszont a read_csv ugy nez ki hogy pd.read_csv
from pandas import Series
from pandas import read_csv

stroke = read_csv('stroke.csv', index_col = 'id', sep = ',' )
print(stroke.head(2))
# Out:
#        gender   age hypertension heart_disease ever_married      work_type  \
# id
# 9046     Male  67.0           No           Yes          Yes        Private
# 51676  Female  61.0           No            No          Yes  Self-employed
#
#       Residence_type  avg_glucose_level   bmi   smoking_status stroke
# id
# 9046           Urban             228.69  36.6  formerly smoked    Yes
# 51676          Rural             202.21   NaN     never smoked    Yes

# %%
portugal_pop = read_csv('portugal_population.csv', index_col = 'date', date_format='YYYY-MM-DD', sep=',')
print(portugal_pop.head(3))

print(portugal_pop.describe())
# Out:
#             BirthsPer1000  Population  GDP_USD  PerCapita_USD  LifeExpectancy
# date
# 1950-12-31         23.869     8416952      NaN            NaN          59.096
# 1951-12-31         23.877     8472644      NaN            NaN          59.504
# 1952-12-31         23.886     8523684      NaN            NaN          59.912
#        BirthsPer1000    Population     GDP_USD  PerCapita_USD  LifeExpectancy
# count      73.000000  7.400000e+01   63.000000      63.000000       74.000000
# mean       15.431014  9.688343e+06  104.164928   10125.669675       72.303676
# std         6.065687  7.163030e+05   92.487691    8801.430387        7.004163
# min         7.699000  8.416952e+06    3.193200     360.499300       59.096000
# 25%        10.581000  8.897459e+06   19.840220    2150.460700       66.458500
# 50%        13.074000  9.989259e+06   89.233599    8958.985300       73.587000
# 75%        22.279000  1.029617e+07  202.910109   19544.780250       78.175000
# ...

# %%
airline_pass = read_csv('airline_passengers.csv', index_col = 'Month', date_format = "YYYY-MM", sep=',')
print(airline_pass.head(3))
# Out:
#          Passengers
# Month
# 1949-01         112
# 1949-02         118
# 1949-03         132

# %%
# from pd import Series   mar egyszer importaltam ezert nem kell csak kiirtam hogy ne felejtsem el hogy ezt a reszet is importalnom kell ha hasznalni akarom. 

passes = Series(airline_pass['Passengers'], index = airline_pass.index, name="passengers szeria")
print(passes.head(3))
print("\n", passes.describe())
# Out:
# Month
# 1949-01    112
# 1949-02    118
# 1949-03    132
# Name: passengers szeria, dtype: int64
#
#  count    144.000000
# mean     280.298611
# std      119.966317
# min      104.000000
# 25%      180.000000
# 50%      265.500000
# 75%      360.500000
# max      622.000000
# Name: passengers szeria, dtype: float64
